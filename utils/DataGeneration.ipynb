# %% [markdown]
# # Data Generation Pipline

# %%
import os
import re
import gzip
import random
import time
import pandas as pd
import numpy as np
from Bio import SeqIO
from pyfaidx import Fasta

# %%
data_folder='E:/refseq/'
genome_folder='E:/masters/virnet/data/1-genomes'
train_test_folder='E:/masters/virnet/data/2-train_test'
fragments_folder='E:/masters/virnet/data/3-fragments/fna'
metagenome_folder='E:/masters/virnet/data/4-metagenome'

# %% [markdown]
# ## 1- Generate Genomes

# %%
def get_taxid(features):
    for feature in features:
        if feature.type == 'source':
            taxid = feature.qualifiers["db_xref"][0].strip('taxon:')
            return (taxid)
    return 0

def load_file(gb_file,file_type,sample,sample_ratio=20):
    random.seed(42)
    genomes=[]
    #if(sample==True and random.randint(0,2)!=0):
    #    return genomes
    with gzip.open(gb_file,"rt") as handle:
        for record in SeqIO.parse(handle, file_type):
            if(sample==True and random.randint(0,sample_ratio)!=0):
                continue
            else:
                #print(record.annotations['source'])
                genome={'id':record.id,'len':len(record),'seq':record.seq,'taxid':'','date':''}
                if(file_type=='genbank'):
                    genome['date']=record.annotations['date']
                    genome['taxid']=get_taxid(record.features)
                genomes.append(genome)
    return genomes  

def load_data(genometype,file_type,output_folder,sample=False,sample_ratio=20):
    start=time.time()
    genome_folder=os.path.join(data_folder,genometype)
    files_list=[]
    if(file_type=='fasta'):
        files_list=[file for file in os.listdir(genome_folder) if file.endswith(".genomic.fna.gz")]
    else:
        files_list=[file for file in os.listdir(genome_folder) if file.endswith(".genomic.gbff.gz")]
    
    count=0
    output_file_name=os.path.join(output_folder,"{0}.fna".format(genometype))
    with open(output_file_name,'w+') as f:
        for i in range(len(files_list)):
            file=files_list[i]
            print('Prasing {1}/{2} file: {0}'.format(file,i+1,len(files_list)))
            gb_file=os.path.join(genome_folder,file)
            file_genomes=load_file(gb_file,file_type,sample,sample_ratio)
            print('Saving {0} genomes from file : {1}'.format(len(file_genomes),file))
            for genome in file_genomes:
                genome_header='> ref_{0}|'.format(genometype)
                for key in genome:
                    if(key!='seq'):
                        genome_header+='{0}={1}|'.format(key,genome[key])
                f.write('{0}\n{1}\n'.format(genome_header,genome['seq']))
            count+=len(file_genomes)
    print('Saved {0} genomes in {1}'.format(count,output_file_name))
    end=time.time()
    print('Time elapased {0:.3f} Minutes'.format((end-start)/60))

# %%
load_data('viral','genbank',genome_folder,sample=False)
# Out:
# Prasing 1/2 file: viral.1.genomic.gbff.gz
# Saving 8557 genomes from file : viral.1.genomic.gbff.gz
# Prasing 2/2 file: viral.2.genomic.gbff.gz
# Saving 999 genomes from file : viral.2.genomic.gbff.gz
# Saved 9556 genomes in E:/masters/virnet/data/1-genomes\viral.fna
# Time elapased 0.936 Minutes

# %%
load_data('archaea','fasta',genome_folder,sample=True,sample_ratio=2)
# Out:
# Prasing 1/6 file: archaea.1.1.genomic.fna.gz
# Saving 1349 genomes from file : archaea.1.1.genomic.fna.gz
# Prasing 2/6 file: archaea.2.1.genomic.fna.gz
# Saving 4351 genomes from file : archaea.2.1.genomic.fna.gz
# Prasing 3/6 file: archaea.3.1.genomic.fna.gz
# Saving 3563 genomes from file : archaea.3.1.genomic.fna.gz
# Prasing 4/6 file: archaea.4.1.genomic.fna.gz
# Saving 2739 genomes from file : archaea.4.1.genomic.fna.gz
# Prasing 5/6 file: archaea.5.1.genomic.fna.gz
# Saving 122 genomes from file : archaea.5.1.genomic.fna.gz
# Prasing 6/6 file: archaea.6.1.genomic.fna.gz
# Saving 80 genomes from file : archaea.6.1.genomic.fna.gz
# Saved 12204 genomes in E:/masters/virnet/data/1-genomes\archaea.fna
# Time elapased 0.633 Minutes

# %%
load_data('bacteria','fasta',genome_folder,sample=True)
# Out:
# Prasing 1/1212 file: bacteria.1.1.genomic.fna.gz
# Saving 13504 genomes from file : bacteria.1.1.genomic.fna.gz
# Prasing 2/1212 file: bacteria.10.1.genomic.fna.gz
# Saving 95 genomes from file : bacteria.10.1.genomic.fna.gz
# Prasing 3/1212 file: bacteria.100.1.genomic.fna.gz
# Saving 137 genomes from file : bacteria.100.1.genomic.fna.gz
# Prasing 4/1212 file: bacteria.1000.1.genomic.fna.gz
# Saving 51 genomes from file : bacteria.1000.1.genomic.fna.gz
# Prasing 5/1212 file: bacteria.1001.1.genomic.fna.gz
# Saving 53 genomes from file : bacteria.1001.1.genomic.fna.gz
# Prasing 6/1212 file: bacteria.1002.1.genomic.fna.gz
# Saving 640 genomes from file : bacteria.1002.1.genomic.fna.gz
# Prasing 7/1212 file: bacteria.1003.1.genomic.fna.gz
# Saving 998 genomes from file : bacteria.1003.1.genomic.fna.gz
# Prasing 8/1212 file: bacteria.1004.1.genomic.fna.gz
# Saving 715 genomes from file : bacteria.1004.1.genomic.fna.gz
# Prasing 9/1212 file: bacteria.1005.1.genomic.fna.gz
# Saving 34 genomes from file : bacteria.1005.1.genomic.fna.gz
# Prasing 10/1212 file: bacteria.1006.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1006.1.genomic.fna.gz
# Prasing 11/1212 file: bacteria.1007.1.genomic.fna.gz
# Saving 10 genomes from file : bacteria.1007.1.genomic.fna.gz
# Prasing 12/1212 file: bacteria.1008.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1008.1.genomic.fna.gz
# Prasing 13/1212 file: bacteria.1009.1.genomic.fna.gz
# Saving 3 genomes from file : bacteria.1009.1.genomic.fna.gz
# Prasing 14/1212 file: bacteria.101.1.genomic.fna.gz
# Saving 852 genomes from file : bacteria.101.1.genomic.fna.gz
# Prasing 15/1212 file: bacteria.1010.1.genomic.fna.gz
# Saving 92 genomes from file : bacteria.1010.1.genomic.fna.gz
# Prasing 16/1212 file: bacteria.1011.1.genomic.fna.gz
# Saving 1 genomes from file : bacteria.1011.1.genomic.fna.gz
# Prasing 17/1212 file: bacteria.1012.1.genomic.fna.gz
# Saving 0 genomes from file : bacteria.1012.1.genomic.fna.gz
# Prasing 18/1212 file: bacteria.1013.1.genomic.fna.gz
# Saving 16 genomes from file : bacteria.1013.1.genomic.fna.gz
# Prasing 19/1212 file: bacteria.1014.1.genomic.fna.gz
# Saving 55 genomes from file : bacteria.1014.1.genomic.fna.gz
# Prasing 20/1212 file: bacteria.1015.1.genomic.fna.gz
# Saving 49 genomes from file : bacteria.1015.1.genomic.fna.gz
# Prasing 21/1212 file: bacteria.1016.1.genomic.fna.gz
# Saving 188 genomes from file : bacteria.1016.1.genomic.fna.gz
# Prasing 22/1212 file: bacteria.1017.1.genomic.fna.gz
# Saving 130 genomes from file : bacteria.1017.1.genomic.fna.gz
# Prasing 23/1212 file: bacteria.1018.1.genomic.fna.gz
# Saving 144 genomes from file : bacteria.1018.1.genomic.fna.gz
# Prasing 24/1212 file: bacteria.1019.1.genomic.fna.gz
# Saving 183 genomes from file : bacteria.1019.1.genomic.fna.gz
# Prasing 25/1212 file: bacteria.102.1.genomic.fna.gz
# Saving 477 genomes from file : bacteria.102.1.genomic.fna.gz
# Prasing 26/1212 file: bacteria.1020.1.genomic.fna.gz
# Saving 153 genomes from file : bacteria.1020.1.genomic.fna.gz
# Prasing 27/1212 file: bacteria.1021.1.genomic.fna.gz
# Saving 220 genomes from file : bacteria.1021.1.genomic.fna.gz
# Prasing 28/1212 file: bacteria.1022.1.genomic.fna.gz
# Saving 201 genomes from file : bacteria.1022.1.genomic.fna.gz
# Prasing 29/1212 file: bacteria.1023.1.genomic.fna.gz
# Saving 241 genomes from file : bacteria.1023.1.genomic.fna.gz
# Prasing 30/1212 file: bacteria.1024.1.genomic.fna.gz
# Saving 200 genomes from file : bacteria.1024.1.genomic.fna.gz
# Prasing 31/1212 file: bacteria.1025.1.genomic.fna.gz
# Saving 96 genomes from file : bacteria.1025.1.genomic.fna.gz
# Prasing 32/1212 file: bacteria.1026.1.genomic.fna.gz
# Saving 154 genomes from file : bacteria.1026.1.genomic.fna.gz
# Prasing 33/1212 file: bacteria.1027.1.genomic.fna.gz
# Saving 139 genomes from file : bacteria.1027.1.genomic.fna.gz
# Prasing 34/1212 file: bacteria.1028.1.genomic.fna.gz
# Saving 141 genomes from file : bacteria.1028.1.genomic.fna.gz
# Prasing 35/1212 file: bacteria.1029.1.genomic.fna.gz
# Saving 250 genomes from file : bacteria.1029.1.genomic.fna.gz
# Prasing 36/1212 file: bacteria.103.1.genomic.fna.gz
# Saving 362 genomes from file : bacteria.103.1.genomic.fna.gz
# Prasing 37/1212 file: bacteria.1030.1.genomic.fna.gz
# Saving 242 genomes from file : bacteria.1030.1.genomic.fna.gz
# Prasing 38/1212 file: bacteria.1031.1.genomic.fna.gz
# Saving 245 genomes from file : bacteria.1031.1.genomic.fna.gz
# Prasing 39/1212 file: bacteria.1032.1.genomic.fna.gz
# Saving 258 genomes from file : bacteria.1032.1.genomic.fna.gz
# Prasing 40/1212 file: bacteria.1033.1.genomic.fna.gz
# Saving 265 genomes from file : bacteria.1033.1.genomic.fna.gz
# Prasing 41/1212 file: bacteria.1034.1.genomic.fna.gz
# Saving 72 genomes from file : bacteria.1034.1.genomic.fna.gz
# Prasing 42/1212 file: bacteria.1035.1.genomic.fna.gz
# Saving 277 genomes from file : bacteria.1035.1.genomic.fna.gz
# Prasing 43/1212 file: bacteria.1036.1.genomic.fna.gz
# Saving 294 genomes from file : bacteria.1036.1.genomic.fna.gz
# Prasing 44/1212 file: bacteria.1037.1.genomic.fna.gz
# Saving 315 genomes from file : bacteria.1037.1.genomic.fna.gz
# Prasing 45/1212 file: bacteria.1038.1.genomic.fna.gz
# Saving 251 genomes from file : bacteria.1038.1.genomic.fna.gz
# Prasing 46/1212 file: bacteria.1039.1.genomic.fna.gz
# Saving 232 genomes from file : bacteria.1039.1.genomic.fna.gz
# Prasing 47/1212 file: bacteria.104.1.genomic.fna.gz
# Saving 506 genomes from file : bacteria.104.1.genomic.fna.gz
# Prasing 48/1212 file: bacteria.1040.1.genomic.fna.gz
# Saving 259 genomes from file : bacteria.1040.1.genomic.fna.gz
# Prasing 49/1212 file: bacteria.1041.1.genomic.fna.gz
# Saving 165 genomes from file : bacteria.1041.1.genomic.fna.gz
# Prasing 50/1212 file: bacteria.1042.1.genomic.fna.gz
# Saving 71 genomes from file : bacteria.1042.1.genomic.fna.gz
# Prasing 51/1212 file: bacteria.1043.1.genomic.fna.gz
# Saving 134 genomes from file : bacteria.1043.1.genomic.fna.gz
# Prasing 52/1212 file: bacteria.1044.1.genomic.fna.gz
# Saving 68 genomes from file : bacteria.1044.1.genomic.fna.gz
# Prasing 53/1212 file: bacteria.1045.1.genomic.fna.gz
# Saving 179 genomes from file : bacteria.1045.1.genomic.fna.gz
# Prasing 54/1212 file: bacteria.1046.1.genomic.fna.gz
# Saving 74 genomes from file : bacteria.1046.1.genomic.fna.gz
# Prasing 55/1212 file: bacteria.1047.1.genomic.fna.gz
# Saving 186 genomes from file : bacteria.1047.1.genomic.fna.gz
# Prasing 56/1212 file: bacteria.1048.1.genomic.fna.gz
# Saving 247 genomes from file : bacteria.1048.1.genomic.fna.gz
# Prasing 57/1212 file: bacteria.1049.1.genomic.fna.gz
# Saving 183 genomes from file : bacteria.1049.1.genomic.fna.gz
# Prasing 58/1212 file: bacteria.105.1.genomic.fna.gz
# Saving 350 genomes from file : bacteria.105.1.genomic.fna.gz
# Prasing 59/1212 file: bacteria.1050.1.genomic.fna.gz
# Saving 148 genomes from file : bacteria.1050.1.genomic.fna.gz
# Prasing 60/1212 file: bacteria.1051.1.genomic.fna.gz
# Saving 168 genomes from file : bacteria.1051.1.genomic.fna.gz
# Prasing 61/1212 file: bacteria.1052.1.genomic.fna.gz
# Saving 62 genomes from file : bacteria.1052.1.genomic.fna.gz
# Prasing 62/1212 file: bacteria.1053.1.genomic.fna.gz
# Saving 27 genomes from file : bacteria.1053.1.genomic.fna.gz
# Prasing 63/1212 file: bacteria.1054.1.genomic.fna.gz
# Saving 136 genomes from file : bacteria.1054.1.genomic.fna.gz
# Prasing 64/1212 file: bacteria.1055.1.genomic.fna.gz
# Saving 65 genomes from file : bacteria.1055.1.genomic.fna.gz
# Prasing 65/1212 file: bacteria.1056.1.genomic.fna.gz
# Saving 58 genomes from file : bacteria.1056.1.genomic.fna.gz
# Prasing 66/1212 file: bacteria.1057.1.genomic.fna.gz
# Saving 28 genomes from file : bacteria.1057.1.genomic.fna.gz
# Prasing 67/1212 file: bacteria.1058.1.genomic.fna.gz
# Saving 47 genomes from file : bacteria.1058.1.genomic.fna.gz
# Prasing 68/1212 file: bacteria.1059.1.genomic.fna.gz
# Saving 55 genomes from file : bacteria.1059.1.genomic.fna.gz
# Prasing 69/1212 file: bacteria.106.1.genomic.fna.gz
# Saving 222 genomes from file : bacteria.106.1.genomic.fna.gz
# Prasing 70/1212 file: bacteria.1060.1.genomic.fna.gz
# Saving 22 genomes from file : bacteria.1060.1.genomic.fna.gz
# Prasing 71/1212 file: bacteria.1061.1.genomic.fna.gz
# Saving 40 genomes from file : bacteria.1061.1.genomic.fna.gz
# Prasing 72/1212 file: bacteria.1062.1.genomic.fna.gz
# Saving 90 genomes from file : bacteria.1062.1.genomic.fna.gz
# Prasing 73/1212 file: bacteria.1063.1.genomic.fna.gz
# Saving 178 genomes from file : bacteria.1063.1.genomic.fna.gz
# Prasing 74/1212 file: bacteria.1064.1.genomic.fna.gz
# Saving 73 genomes from file : bacteria.1064.1.genomic.fna.gz
# Prasing 75/1212 file: bacteria.1065.1.genomic.fna.gz
# Saving 1 genomes from file : bacteria.1065.1.genomic.fna.gz
# Prasing 76/1212 file: bacteria.1066.1.genomic.fna.gz
# Saving 10 genomes from file : bacteria.1066.1.genomic.fna.gz
# Prasing 77/1212 file: bacteria.1067.1.genomic.fna.gz
# Saving 54 genomes from file : bacteria.1067.1.genomic.fna.gz
# Prasing 78/1212 file: bacteria.1068.1.genomic.fna.gz
# Saving 39 genomes from file : bacteria.1068.1.genomic.fna.gz
# Prasing 79/1212 file: bacteria.1069.1.genomic.fna.gz
# Saving 189 genomes from file : bacteria.1069.1.genomic.fna.gz
# Prasing 80/1212 file: bacteria.107.1.genomic.fna.gz
# Saving 374 genomes from file : bacteria.107.1.genomic.fna.gz
# Prasing 81/1212 file: bacteria.1070.1.genomic.fna.gz
# Saving 313 genomes from file : bacteria.1070.1.genomic.fna.gz
# Prasing 82/1212 file: bacteria.1071.1.genomic.fna.gz
# Saving 128 genomes from file : bacteria.1071.1.genomic.fna.gz
# Prasing 83/1212 file: bacteria.1072.1.genomic.fna.gz
# Saving 29 genomes from file : bacteria.1072.1.genomic.fna.gz
# Prasing 84/1212 file: bacteria.1073.1.genomic.fna.gz
# Saving 6 genomes from file : bacteria.1073.1.genomic.fna.gz
# Prasing 85/1212 file: bacteria.1074.1.genomic.fna.gz
# Saving 27 genomes from file : bacteria.1074.1.genomic.fna.gz
# Prasing 86/1212 file: bacteria.1075.1.genomic.fna.gz
# Saving 1 genomes from file : bacteria.1075.1.genomic.fna.gz
# Prasing 87/1212 file: bacteria.1076.1.genomic.fna.gz
# Saving 203 genomes from file : bacteria.1076.1.genomic.fna.gz
# Prasing 88/1212 file: bacteria.1077.1.genomic.fna.gz
# Saving 167 genomes from file : bacteria.1077.1.genomic.fna.gz
# Prasing 89/1212 file: bacteria.1078.1.genomic.fna.gz
# Saving 185 genomes from file : bacteria.1078.1.genomic.fna.gz
# Prasing 90/1212 file: bacteria.1079.1.genomic.fna.gz
# Saving 101 genomes from file : bacteria.1079.1.genomic.fna.gz
# Prasing 91/1212 file: bacteria.108.1.genomic.fna.gz
# Saving 456 genomes from file : bacteria.108.1.genomic.fna.gz
# Prasing 92/1212 file: bacteria.1080.1.genomic.fna.gz
# Saving 163 genomes from file : bacteria.1080.1.genomic.fna.gz
# Prasing 93/1212 file: bacteria.1081.1.genomic.fna.gz
# Saving 25 genomes from file : bacteria.1081.1.genomic.fna.gz
# Prasing 94/1212 file: bacteria.1082.1.genomic.fna.gz
# Saving 169 genomes from file : bacteria.1082.1.genomic.fna.gz
# Prasing 95/1212 file: bacteria.1083.1.genomic.fna.gz
# Saving 66 genomes from file : bacteria.1083.1.genomic.fna.gz
# Prasing 96/1212 file: bacteria.1084.1.genomic.fna.gz
# Saving 36 genomes from file : bacteria.1084.1.genomic.fna.gz
# Prasing 97/1212 file: bacteria.1085.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1085.1.genomic.fna.gz
# Prasing 98/1212 file: bacteria.1086.1.genomic.fna.gz
# Saving 12 genomes from file : bacteria.1086.1.genomic.fna.gz
# Prasing 99/1212 file: bacteria.1087.1.genomic.fna.gz
# Saving 22 genomes from file : bacteria.1087.1.genomic.fna.gz
# Prasing 100/1212 file: bacteria.1088.1.genomic.fna.gz
# Saving 312 genomes from file : bacteria.1088.1.genomic.fna.gz
# Prasing 101/1212 file: bacteria.1089.1.genomic.fna.gz
# Saving 579 genomes from file : bacteria.1089.1.genomic.fna.gz
# Prasing 102/1212 file: bacteria.109.1.genomic.fna.gz
# Saving 140 genomes from file : bacteria.109.1.genomic.fna.gz
# Prasing 103/1212 file: bacteria.1090.1.genomic.fna.gz
# Saving 0 genomes from file : bacteria.1090.1.genomic.fna.gz
# Prasing 104/1212 file: bacteria.1091.1.genomic.fna.gz
# Saving 17 genomes from file : bacteria.1091.1.genomic.fna.gz
# Prasing 105/1212 file: bacteria.1092.1.genomic.fna.gz
# Saving 4 genomes from file : bacteria.1092.1.genomic.fna.gz
# Prasing 106/1212 file: bacteria.1093.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1093.1.genomic.fna.gz
# Prasing 107/1212 file: bacteria.1094.1.genomic.fna.gz
# Saving 5 genomes from file : bacteria.1094.1.genomic.fna.gz
# Prasing 108/1212 file: bacteria.1095.1.genomic.fna.gz
# Saving 9 genomes from file : bacteria.1095.1.genomic.fna.gz
# Prasing 109/1212 file: bacteria.1096.1.genomic.fna.gz
# Saving 63 genomes from file : bacteria.1096.1.genomic.fna.gz
# Prasing 110/1212 file: bacteria.1097.1.genomic.fna.gz
# Saving 124 genomes from file : bacteria.1097.1.genomic.fna.gz
# Prasing 111/1212 file: bacteria.1098.1.genomic.fna.gz
# Saving 6 genomes from file : bacteria.1098.1.genomic.fna.gz
# Prasing 112/1212 file: bacteria.1099.1.genomic.fna.gz
# Saving 135 genomes from file : bacteria.1099.1.genomic.fna.gz
# Prasing 113/1212 file: bacteria.11.1.genomic.fna.gz
# Saving 742 genomes from file : bacteria.11.1.genomic.fna.gz
# Prasing 114/1212 file: bacteria.110.1.genomic.fna.gz
# Saving 246 genomes from file : bacteria.110.1.genomic.fna.gz
# Prasing 115/1212 file: bacteria.1100.1.genomic.fna.gz
# Saving 28 genomes from file : bacteria.1100.1.genomic.fna.gz
# Prasing 116/1212 file: bacteria.1101.1.genomic.fna.gz
# Saving 35 genomes from file : bacteria.1101.1.genomic.fna.gz
# Prasing 117/1212 file: bacteria.1102.1.genomic.fna.gz
# Saving 70 genomes from file : bacteria.1102.1.genomic.fna.gz
# Prasing 118/1212 file: bacteria.1103.1.genomic.fna.gz
# Saving 300 genomes from file : bacteria.1103.1.genomic.fna.gz
# Prasing 119/1212 file: bacteria.1104.1.genomic.fna.gz
# Saving 169 genomes from file : bacteria.1104.1.genomic.fna.gz
# Prasing 120/1212 file: bacteria.1105.1.genomic.fna.gz
# Saving 54 genomes from file : bacteria.1105.1.genomic.fna.gz
# Prasing 121/1212 file: bacteria.1106.1.genomic.fna.gz
# Saving 122 genomes from file : bacteria.1106.1.genomic.fna.gz
# Prasing 122/1212 file: bacteria.1107.1.genomic.fna.gz
# Saving 26 genomes from file : bacteria.1107.1.genomic.fna.gz
# Prasing 123/1212 file: bacteria.1108.1.genomic.fna.gz
# Saving 33 genomes from file : bacteria.1108.1.genomic.fna.gz
# Prasing 124/1212 file: bacteria.1109.1.genomic.fna.gz
# Saving 19 genomes from file : bacteria.1109.1.genomic.fna.gz
# Prasing 125/1212 file: bacteria.111.1.genomic.fna.gz
# Saving 202 genomes from file : bacteria.111.1.genomic.fna.gz
# Prasing 126/1212 file: bacteria.1110.1.genomic.fna.gz
# Saving 143 genomes from file : bacteria.1110.1.genomic.fna.gz
# Prasing 127/1212 file: bacteria.1111.1.genomic.fna.gz
# Saving 34 genomes from file : bacteria.1111.1.genomic.fna.gz
# Prasing 128/1212 file: bacteria.1112.1.genomic.fna.gz
# Saving 22 genomes from file : bacteria.1112.1.genomic.fna.gz
# Prasing 129/1212 file: bacteria.1113.1.genomic.fna.gz
# Saving 27 genomes from file : bacteria.1113.1.genomic.fna.gz
# Prasing 130/1212 file: bacteria.1114.1.genomic.fna.gz
# Saving 21 genomes from file : bacteria.1114.1.genomic.fna.gz
# Prasing 131/1212 file: bacteria.1115.1.genomic.fna.gz
# Saving 51 genomes from file : bacteria.1115.1.genomic.fna.gz
# Prasing 132/1212 file: bacteria.1116.1.genomic.fna.gz
# Saving 41 genomes from file : bacteria.1116.1.genomic.fna.gz
# Prasing 133/1212 file: bacteria.1117.1.genomic.fna.gz
# Saving 159 genomes from file : bacteria.1117.1.genomic.fna.gz
# Prasing 134/1212 file: bacteria.1118.1.genomic.fna.gz
# Saving 20 genomes from file : bacteria.1118.1.genomic.fna.gz
# Prasing 135/1212 file: bacteria.1119.1.genomic.fna.gz
# Saving 70 genomes from file : bacteria.1119.1.genomic.fna.gz
# Prasing 136/1212 file: bacteria.112.1.genomic.fna.gz
# Saving 191 genomes from file : bacteria.112.1.genomic.fna.gz
# Prasing 137/1212 file: bacteria.1120.1.genomic.fna.gz
# Saving 184 genomes from file : bacteria.1120.1.genomic.fna.gz
# Prasing 138/1212 file: bacteria.1121.1.genomic.fna.gz
# Saving 84 genomes from file : bacteria.1121.1.genomic.fna.gz
# Prasing 139/1212 file: bacteria.1122.1.genomic.fna.gz
# Saving 235 genomes from file : bacteria.1122.1.genomic.fna.gz
# Prasing 140/1212 file: bacteria.1123.1.genomic.fna.gz
# Saving 112 genomes from file : bacteria.1123.1.genomic.fna.gz
# Prasing 141/1212 file: bacteria.1124.1.genomic.fna.gz
# Saving 18 genomes from file : bacteria.1124.1.genomic.fna.gz
# Prasing 142/1212 file: bacteria.1125.1.genomic.fna.gz
# Saving 61 genomes from file : bacteria.1125.1.genomic.fna.gz
# Prasing 143/1212 file: bacteria.1126.1.genomic.fna.gz
# Saving 21 genomes from file : bacteria.1126.1.genomic.fna.gz
# Prasing 144/1212 file: bacteria.1127.1.genomic.fna.gz
# Saving 34 genomes from file : bacteria.1127.1.genomic.fna.gz
# Prasing 145/1212 file: bacteria.1128.1.genomic.fna.gz
# Saving 40 genomes from file : bacteria.1128.1.genomic.fna.gz
# Prasing 146/1212 file: bacteria.1129.1.genomic.fna.gz
# Saving 74 genomes from file : bacteria.1129.1.genomic.fna.gz
# Prasing 147/1212 file: bacteria.113.1.genomic.fna.gz
# Saving 221 genomes from file : bacteria.113.1.genomic.fna.gz
# Prasing 148/1212 file: bacteria.1130.1.genomic.fna.gz
# Saving 82 genomes from file : bacteria.1130.1.genomic.fna.gz
# Prasing 149/1212 file: bacteria.1131.1.genomic.fna.gz
# Saving 77 genomes from file : bacteria.1131.1.genomic.fna.gz
# Prasing 150/1212 file: bacteria.1132.1.genomic.fna.gz
# Saving 135 genomes from file : bacteria.1132.1.genomic.fna.gz
# Prasing 151/1212 file: bacteria.1133.1.genomic.fna.gz
# Saving 67 genomes from file : bacteria.1133.1.genomic.fna.gz
# Prasing 152/1212 file: bacteria.1134.1.genomic.fna.gz
# Saving 165 genomes from file : bacteria.1134.1.genomic.fna.gz
# Prasing 153/1212 file: bacteria.1135.1.genomic.fna.gz
# Saving 67 genomes from file : bacteria.1135.1.genomic.fna.gz
# Prasing 154/1212 file: bacteria.1136.1.genomic.fna.gz
# Saving 16 genomes from file : bacteria.1136.1.genomic.fna.gz
# Prasing 155/1212 file: bacteria.1137.1.genomic.fna.gz
# Saving 14 genomes from file : bacteria.1137.1.genomic.fna.gz
# Prasing 156/1212 file: bacteria.1138.1.genomic.fna.gz
# Saving 7 genomes from file : bacteria.1138.1.genomic.fna.gz
# Prasing 157/1212 file: bacteria.1139.1.genomic.fna.gz
# Saving 212 genomes from file : bacteria.1139.1.genomic.fna.gz
# Prasing 158/1212 file: bacteria.114.1.genomic.fna.gz
# Saving 192 genomes from file : bacteria.114.1.genomic.fna.gz
# Prasing 159/1212 file: bacteria.1140.1.genomic.fna.gz
# Saving 501 genomes from file : bacteria.1140.1.genomic.fna.gz
# Prasing 160/1212 file: bacteria.1141.1.genomic.fna.gz
# Saving 491 genomes from file : bacteria.1141.1.genomic.fna.gz
# Prasing 161/1212 file: bacteria.1142.1.genomic.fna.gz
# Saving 497 genomes from file : bacteria.1142.1.genomic.fna.gz
# Prasing 162/1212 file: bacteria.1143.1.genomic.fna.gz
# Saving 330 genomes from file : bacteria.1143.1.genomic.fna.gz
# Prasing 163/1212 file: bacteria.1144.1.genomic.fna.gz
# Saving 513 genomes from file : bacteria.1144.1.genomic.fna.gz
# Prasing 164/1212 file: bacteria.1145.1.genomic.fna.gz
# Saving 29 genomes from file : bacteria.1145.1.genomic.fna.gz
# Prasing 165/1212 file: bacteria.1146.1.genomic.fna.gz
# Saving 96 genomes from file : bacteria.1146.1.genomic.fna.gz
# Prasing 166/1212 file: bacteria.1147.1.genomic.fna.gz
# Saving 54 genomes from file : bacteria.1147.1.genomic.fna.gz
# Prasing 167/1212 file: bacteria.1148.1.genomic.fna.gz
# Saving 26 genomes from file : bacteria.1148.1.genomic.fna.gz
# Prasing 168/1212 file: bacteria.1149.1.genomic.fna.gz
# Saving 92 genomes from file : bacteria.1149.1.genomic.fna.gz
# Prasing 169/1212 file: bacteria.115.1.genomic.fna.gz
# Saving 193 genomes from file : bacteria.115.1.genomic.fna.gz
# Prasing 170/1212 file: bacteria.1150.1.genomic.fna.gz
# Saving 112 genomes from file : bacteria.1150.1.genomic.fna.gz
# Prasing 171/1212 file: bacteria.1151.1.genomic.fna.gz
# Saving 210 genomes from file : bacteria.1151.1.genomic.fna.gz
# Prasing 172/1212 file: bacteria.1152.1.genomic.fna.gz
# Saving 122 genomes from file : bacteria.1152.1.genomic.fna.gz
# Prasing 173/1212 file: bacteria.1153.1.genomic.fna.gz
# Saving 70 genomes from file : bacteria.1153.1.genomic.fna.gz
# Prasing 174/1212 file: bacteria.1154.1.genomic.fna.gz
# Saving 77 genomes from file : bacteria.1154.1.genomic.fna.gz
# Prasing 175/1212 file: bacteria.1155.1.genomic.fna.gz
# Saving 67 genomes from file : bacteria.1155.1.genomic.fna.gz
# Prasing 176/1212 file: bacteria.1156.1.genomic.fna.gz
# Saving 7 genomes from file : bacteria.1156.1.genomic.fna.gz
# Prasing 177/1212 file: bacteria.1157.1.genomic.fna.gz
# Saving 169 genomes from file : bacteria.1157.1.genomic.fna.gz
# Prasing 178/1212 file: bacteria.1158.1.genomic.fna.gz
# Saving 78 genomes from file : bacteria.1158.1.genomic.fna.gz
# Prasing 179/1212 file: bacteria.1159.1.genomic.fna.gz
# Saving 53 genomes from file : bacteria.1159.1.genomic.fna.gz
# Prasing 180/1212 file: bacteria.116.1.genomic.fna.gz
# Saving 194 genomes from file : bacteria.116.1.genomic.fna.gz
# Prasing 181/1212 file: bacteria.1160.1.genomic.fna.gz
# Saving 3 genomes from file : bacteria.1160.1.genomic.fna.gz
# Prasing 182/1212 file: bacteria.1161.1.genomic.fna.gz
# Saving 8 genomes from file : bacteria.1161.1.genomic.fna.gz
# Prasing 183/1212 file: bacteria.1162.1.genomic.fna.gz
# Saving 67 genomes from file : bacteria.1162.1.genomic.fna.gz
# Prasing 184/1212 file: bacteria.1163.1.genomic.fna.gz
# Saving 44 genomes from file : bacteria.1163.1.genomic.fna.gz
# Prasing 185/1212 file: bacteria.1164.1.genomic.fna.gz
# Saving 66 genomes from file : bacteria.1164.1.genomic.fna.gz
# Prasing 186/1212 file: bacteria.1165.1.genomic.fna.gz
# Saving 48 genomes from file : bacteria.1165.1.genomic.fna.gz
# Prasing 187/1212 file: bacteria.1166.1.genomic.fna.gz
# Saving 67 genomes from file : bacteria.1166.1.genomic.fna.gz
# Prasing 188/1212 file: bacteria.1167.1.genomic.fna.gz
# Saving 77 genomes from file : bacteria.1167.1.genomic.fna.gz
# Prasing 189/1212 file: bacteria.1168.1.genomic.fna.gz
# Saving 102 genomes from file : bacteria.1168.1.genomic.fna.gz
# Prasing 190/1212 file: bacteria.1169.1.genomic.fna.gz
# Saving 42 genomes from file : bacteria.1169.1.genomic.fna.gz
# Prasing 191/1212 file: bacteria.117.1.genomic.fna.gz
# Saving 211 genomes from file : bacteria.117.1.genomic.fna.gz
# Prasing 192/1212 file: bacteria.1170.1.genomic.fna.gz
# Saving 45 genomes from file : bacteria.1170.1.genomic.fna.gz
# Prasing 193/1212 file: bacteria.1171.1.genomic.fna.gz
# Saving 77 genomes from file : bacteria.1171.1.genomic.fna.gz
# Prasing 194/1212 file: bacteria.1172.1.genomic.fna.gz
# Saving 139 genomes from file : bacteria.1172.1.genomic.fna.gz
# Prasing 195/1212 file: bacteria.1173.1.genomic.fna.gz
# Saving 50 genomes from file : bacteria.1173.1.genomic.fna.gz
# Prasing 196/1212 file: bacteria.1174.1.genomic.fna.gz
# Saving 8 genomes from file : bacteria.1174.1.genomic.fna.gz
# Prasing 197/1212 file: bacteria.1175.1.genomic.fna.gz
# Saving 166 genomes from file : bacteria.1175.1.genomic.fna.gz
# Prasing 198/1212 file: bacteria.1176.1.genomic.fna.gz
# Saving 12 genomes from file : bacteria.1176.1.genomic.fna.gz
# Prasing 199/1212 file: bacteria.1177.1.genomic.fna.gz
# Saving 45 genomes from file : bacteria.1177.1.genomic.fna.gz
# Prasing 200/1212 file: bacteria.1178.1.genomic.fna.gz
# Saving 106 genomes from file : bacteria.1178.1.genomic.fna.gz
# Prasing 201/1212 file: bacteria.1179.1.genomic.fna.gz
# Saving 46 genomes from file : bacteria.1179.1.genomic.fna.gz
# Prasing 202/1212 file: bacteria.118.1.genomic.fna.gz
# Saving 284 genomes from file : bacteria.118.1.genomic.fna.gz
# Prasing 203/1212 file: bacteria.1180.1.genomic.fna.gz
# Saving 17 genomes from file : bacteria.1180.1.genomic.fna.gz
# Prasing 204/1212 file: bacteria.1181.1.genomic.fna.gz
# Saving 50 genomes from file : bacteria.1181.1.genomic.fna.gz
# Prasing 205/1212 file: bacteria.1182.1.genomic.fna.gz
# Saving 7 genomes from file : bacteria.1182.1.genomic.fna.gz
# Prasing 206/1212 file: bacteria.1183.1.genomic.fna.gz
# Saving 9 genomes from file : bacteria.1183.1.genomic.fna.gz
# Prasing 207/1212 file: bacteria.1184.1.genomic.fna.gz
# Saving 20 genomes from file : bacteria.1184.1.genomic.fna.gz
# Prasing 208/1212 file: bacteria.1185.1.genomic.fna.gz
# Saving 6 genomes from file : bacteria.1185.1.genomic.fna.gz
# Prasing 209/1212 file: bacteria.1186.1.genomic.fna.gz
# Saving 38 genomes from file : bacteria.1186.1.genomic.fna.gz
# Prasing 210/1212 file: bacteria.1187.1.genomic.fna.gz
# Saving 18 genomes from file : bacteria.1187.1.genomic.fna.gz
# Prasing 211/1212 file: bacteria.1188.1.genomic.fna.gz
# Saving 43 genomes from file : bacteria.1188.1.genomic.fna.gz
# Prasing 212/1212 file: bacteria.1189.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1189.1.genomic.fna.gz
# Prasing 213/1212 file: bacteria.119.1.genomic.fna.gz
# Saving 331 genomes from file : bacteria.119.1.genomic.fna.gz
# Prasing 214/1212 file: bacteria.1190.1.genomic.fna.gz
# Saving 20 genomes from file : bacteria.1190.1.genomic.fna.gz
# Prasing 215/1212 file: bacteria.1191.1.genomic.fna.gz
# Saving 15 genomes from file : bacteria.1191.1.genomic.fna.gz
# Prasing 216/1212 file: bacteria.1192.1.genomic.fna.gz
# Saving 10 genomes from file : bacteria.1192.1.genomic.fna.gz
# Prasing 217/1212 file: bacteria.1193.1.genomic.fna.gz
# Saving 13 genomes from file : bacteria.1193.1.genomic.fna.gz
# Prasing 218/1212 file: bacteria.1194.1.genomic.fna.gz
# Saving 8 genomes from file : bacteria.1194.1.genomic.fna.gz
# Prasing 219/1212 file: bacteria.1195.1.genomic.fna.gz
# Saving 0 genomes from file : bacteria.1195.1.genomic.fna.gz
# Prasing 220/1212 file: bacteria.1196.1.genomic.fna.gz
# Saving 14 genomes from file : bacteria.1196.1.genomic.fna.gz
# Prasing 221/1212 file: bacteria.1197.1.genomic.fna.gz
# Saving 6 genomes from file : bacteria.1197.1.genomic.fna.gz
# Prasing 222/1212 file: bacteria.1198.1.genomic.fna.gz
# Saving 16 genomes from file : bacteria.1198.1.genomic.fna.gz
# Prasing 223/1212 file: bacteria.1199.1.genomic.fna.gz
# Saving 11 genomes from file : bacteria.1199.1.genomic.fna.gz
# Prasing 224/1212 file: bacteria.12.1.genomic.fna.gz
# Saving 426 genomes from file : bacteria.12.1.genomic.fna.gz
# Prasing 225/1212 file: bacteria.120.1.genomic.fna.gz
# Saving 286 genomes from file : bacteria.120.1.genomic.fna.gz
# Prasing 226/1212 file: bacteria.1200.1.genomic.fna.gz
# Saving 85 genomes from file : bacteria.1200.1.genomic.fna.gz
# Prasing 227/1212 file: bacteria.1201.1.genomic.fna.gz
# Saving 12 genomes from file : bacteria.1201.1.genomic.fna.gz
# Prasing 228/1212 file: bacteria.1202.1.genomic.fna.gz
# Saving 16 genomes from file : bacteria.1202.1.genomic.fna.gz
# Prasing 229/1212 file: bacteria.1203.1.genomic.fna.gz
# Saving 25 genomes from file : bacteria.1203.1.genomic.fna.gz
# Prasing 230/1212 file: bacteria.1204.1.genomic.fna.gz
# Saving 28 genomes from file : bacteria.1204.1.genomic.fna.gz
# Prasing 231/1212 file: bacteria.1205.1.genomic.fna.gz
# Saving 32 genomes from file : bacteria.1205.1.genomic.fna.gz
# Prasing 232/1212 file: bacteria.1206.1.genomic.fna.gz
# Saving 50 genomes from file : bacteria.1206.1.genomic.fna.gz
# Prasing 233/1212 file: bacteria.1207.1.genomic.fna.gz
# Saving 10 genomes from file : bacteria.1207.1.genomic.fna.gz
# Prasing 234/1212 file: bacteria.1208.1.genomic.fna.gz
# Saving 47 genomes from file : bacteria.1208.1.genomic.fna.gz
# Prasing 235/1212 file: bacteria.1209.1.genomic.fna.gz
# Saving 105 genomes from file : bacteria.1209.1.genomic.fna.gz
# Prasing 236/1212 file: bacteria.121.1.genomic.fna.gz
# Saving 103 genomes from file : bacteria.121.1.genomic.fna.gz
# Prasing 237/1212 file: bacteria.1210.1.genomic.fna.gz
# Saving 5 genomes from file : bacteria.1210.1.genomic.fna.gz
# Prasing 238/1212 file: bacteria.1211.1.genomic.fna.gz
# Saving 22 genomes from file : bacteria.1211.1.genomic.fna.gz
# Prasing 239/1212 file: bacteria.1212.1.genomic.fna.gz
# Saving 14 genomes from file : bacteria.1212.1.genomic.fna.gz
# Prasing 240/1212 file: bacteria.122.1.genomic.fna.gz
# Saving 340 genomes from file : bacteria.122.1.genomic.fna.gz
# Prasing 241/1212 file: bacteria.123.1.genomic.fna.gz
# Saving 241 genomes from file : bacteria.123.1.genomic.fna.gz
# Prasing 242/1212 file: bacteria.124.1.genomic.fna.gz
# Saving 173 genomes from file : bacteria.124.1.genomic.fna.gz
# Prasing 243/1212 file: bacteria.125.1.genomic.fna.gz
# Saving 216 genomes from file : bacteria.125.1.genomic.fna.gz
# Prasing 244/1212 file: bacteria.126.1.genomic.fna.gz
# Saving 168 genomes from file : bacteria.126.1.genomic.fna.gz
# Prasing 245/1212 file: bacteria.127.1.genomic.fna.gz
# Saving 214 genomes from file : bacteria.127.1.genomic.fna.gz
# Prasing 246/1212 file: bacteria.128.1.genomic.fna.gz
# Saving 179 genomes from file : bacteria.128.1.genomic.fna.gz
# Prasing 247/1212 file: bacteria.129.1.genomic.fna.gz
# Saving 210 genomes from file : bacteria.129.1.genomic.fna.gz
# Prasing 248/1212 file: bacteria.13.1.genomic.fna.gz
# Saving 426 genomes from file : bacteria.13.1.genomic.fna.gz
# Prasing 249/1212 file: bacteria.130.1.genomic.fna.gz
# Saving 185 genomes from file : bacteria.130.1.genomic.fna.gz
# Prasing 250/1212 file: bacteria.131.1.genomic.fna.gz
# Saving 319 genomes from file : bacteria.131.1.genomic.fna.gz
# Prasing 251/1212 file: bacteria.132.1.genomic.fna.gz
# Saving 198 genomes from file : bacteria.132.1.genomic.fna.gz
# Prasing 252/1212 file: bacteria.133.1.genomic.fna.gz
# Saving 202 genomes from file : bacteria.133.1.genomic.fna.gz
# Prasing 253/1212 file: bacteria.134.1.genomic.fna.gz
# Saving 222 genomes from file : bacteria.134.1.genomic.fna.gz
# Prasing 254/1212 file: bacteria.135.1.genomic.fna.gz
# Saving 215 genomes from file : bacteria.135.1.genomic.fna.gz
# Prasing 255/1212 file: bacteria.136.1.genomic.fna.gz
# Saving 246 genomes from file : bacteria.136.1.genomic.fna.gz
# Prasing 256/1212 file: bacteria.137.1.genomic.fna.gz
# Saving 255 genomes from file : bacteria.137.1.genomic.fna.gz
# Prasing 257/1212 file: bacteria.138.1.genomic.fna.gz
# Saving 251 genomes from file : bacteria.138.1.genomic.fna.gz
# Prasing 258/1212 file: bacteria.139.1.genomic.fna.gz
# Saving 274 genomes from file : bacteria.139.1.genomic.fna.gz
# Prasing 259/1212 file: bacteria.14.1.genomic.fna.gz
# Saving 295 genomes from file : bacteria.14.1.genomic.fna.gz
# Prasing 260/1212 file: bacteria.140.1.genomic.fna.gz
# Saving 357 genomes from file : bacteria.140.1.genomic.fna.gz
# Prasing 261/1212 file: bacteria.141.1.genomic.fna.gz
# Saving 95 genomes from file : bacteria.141.1.genomic.fna.gz
# Prasing 262/1212 file: bacteria.142.1.genomic.fna.gz
# Saving 277 genomes from file : bacteria.142.1.genomic.fna.gz
# Prasing 263/1212 file: bacteria.143.1.genomic.fna.gz
# Saving 340 genomes from file : bacteria.143.1.genomic.fna.gz
# Prasing 264/1212 file: bacteria.144.1.genomic.fna.gz
# Saving 238 genomes from file : bacteria.144.1.genomic.fna.gz
# Prasing 265/1212 file: bacteria.145.1.genomic.fna.gz
# Saving 304 genomes from file : bacteria.145.1.genomic.fna.gz
# Prasing 266/1212 file: bacteria.146.1.genomic.fna.gz
# Saving 202 genomes from file : bacteria.146.1.genomic.fna.gz
# Prasing 267/1212 file: bacteria.147.1.genomic.fna.gz
# Saving 204 genomes from file : bacteria.147.1.genomic.fna.gz
# Prasing 268/1212 file: bacteria.148.1.genomic.fna.gz
# Saving 191 genomes from file : bacteria.148.1.genomic.fna.gz
# Prasing 269/1212 file: bacteria.149.1.genomic.fna.gz
# Saving 154 genomes from file : bacteria.149.1.genomic.fna.gz
# Prasing 270/1212 file: bacteria.15.1.genomic.fna.gz
# Saving 213 genomes from file : bacteria.15.1.genomic.fna.gz
# Prasing 271/1212 file: bacteria.150.1.genomic.fna.gz
# Saving 313 genomes from file : bacteria.150.1.genomic.fna.gz
# Prasing 272/1212 file: bacteria.151.1.genomic.fna.gz
# Saving 191 genomes from file : bacteria.151.1.genomic.fna.gz
# Prasing 273/1212 file: bacteria.152.1.genomic.fna.gz
# Saving 147 genomes from file : bacteria.152.1.genomic.fna.gz
# Prasing 274/1212 file: bacteria.153.1.genomic.fna.gz
# Saving 315 genomes from file : bacteria.153.1.genomic.fna.gz
# Prasing 275/1212 file: bacteria.154.1.genomic.fna.gz
# Saving 243 genomes from file : bacteria.154.1.genomic.fna.gz
# Prasing 276/1212 file: bacteria.155.1.genomic.fna.gz
# Saving 151 genomes from file : bacteria.155.1.genomic.fna.gz
# Prasing 277/1212 file: bacteria.156.1.genomic.fna.gz
# Saving 83 genomes from file : bacteria.156.1.genomic.fna.gz
# Prasing 278/1212 file: bacteria.157.1.genomic.fna.gz
# Saving 593 genomes from file : bacteria.157.1.genomic.fna.gz
# Prasing 279/1212 file: bacteria.158.1.genomic.fna.gz
# Saving 455 genomes from file : bacteria.158.1.genomic.fna.gz
# Prasing 280/1212 file: bacteria.159.1.genomic.fna.gz
# Saving 300 genomes from file : bacteria.159.1.genomic.fna.gz
# Prasing 281/1212 file: bacteria.16.1.genomic.fna.gz
# Saving 212 genomes from file : bacteria.16.1.genomic.fna.gz
# Prasing 282/1212 file: bacteria.160.1.genomic.fna.gz
# Saving 345 genomes from file : bacteria.160.1.genomic.fna.gz
# Prasing 283/1212 file: bacteria.161.1.genomic.fna.gz
# Saving 360 genomes from file : bacteria.161.1.genomic.fna.gz
# Prasing 284/1212 file: bacteria.162.1.genomic.fna.gz
# Saving 296 genomes from file : bacteria.162.1.genomic.fna.gz
# Prasing 285/1212 file: bacteria.163.1.genomic.fna.gz
# Saving 264 genomes from file : bacteria.163.1.genomic.fna.gz
# Prasing 286/1212 file: bacteria.164.1.genomic.fna.gz
# Saving 358 genomes from file : bacteria.164.1.genomic.fna.gz
# Prasing 287/1212 file: bacteria.165.1.genomic.fna.gz
# Saving 159 genomes from file : bacteria.165.1.genomic.fna.gz
# Prasing 288/1212 file: bacteria.166.1.genomic.fna.gz
# Saving 614 genomes from file : bacteria.166.1.genomic.fna.gz
# Prasing 289/1212 file: bacteria.167.1.genomic.fna.gz
# Saving 242 genomes from file : bacteria.167.1.genomic.fna.gz
# Prasing 290/1212 file: bacteria.168.1.genomic.fna.gz
# Saving 262 genomes from file : bacteria.168.1.genomic.fna.gz
# Prasing 291/1212 file: bacteria.169.1.genomic.fna.gz
# Saving 317 genomes from file : bacteria.169.1.genomic.fna.gz
# Prasing 292/1212 file: bacteria.17.1.genomic.fna.gz
# Saving 190 genomes from file : bacteria.17.1.genomic.fna.gz
# Prasing 293/1212 file: bacteria.170.1.genomic.fna.gz
# Saving 83 genomes from file : bacteria.170.1.genomic.fna.gz
# Prasing 294/1212 file: bacteria.171.1.genomic.fna.gz
# Saving 225 genomes from file : bacteria.171.1.genomic.fna.gz
# Prasing 295/1212 file: bacteria.172.1.genomic.fna.gz
# Saving 257 genomes from file : bacteria.172.1.genomic.fna.gz
# Prasing 296/1212 file: bacteria.173.1.genomic.fna.gz
# Saving 296 genomes from file : bacteria.173.1.genomic.fna.gz
# Prasing 297/1212 file: bacteria.174.1.genomic.fna.gz
# Saving 278 genomes from file : bacteria.174.1.genomic.fna.gz
# Prasing 298/1212 file: bacteria.175.1.genomic.fna.gz
# Saving 302 genomes from file : bacteria.175.1.genomic.fna.gz
# Prasing 299/1212 file: bacteria.176.1.genomic.fna.gz
# Saving 407 genomes from file : bacteria.176.1.genomic.fna.gz
# Prasing 300/1212 file: bacteria.177.1.genomic.fna.gz
# Saving 263 genomes from file : bacteria.177.1.genomic.fna.gz
# Prasing 301/1212 file: bacteria.178.1.genomic.fna.gz
# Saving 420 genomes from file : bacteria.178.1.genomic.fna.gz
# Prasing 302/1212 file: bacteria.179.1.genomic.fna.gz
# Saving 482 genomes from file : bacteria.179.1.genomic.fna.gz
# Prasing 303/1212 file: bacteria.18.1.genomic.fna.gz
# Saving 249 genomes from file : bacteria.18.1.genomic.fna.gz
# Prasing 304/1212 file: bacteria.180.1.genomic.fna.gz
# Saving 618 genomes from file : bacteria.180.1.genomic.fna.gz
# Prasing 305/1212 file: bacteria.181.1.genomic.fna.gz
# Saving 835 genomes from file : bacteria.181.1.genomic.fna.gz
# Prasing 306/1212 file: bacteria.182.1.genomic.fna.gz
# Saving 672 genomes from file : bacteria.182.1.genomic.fna.gz
# Prasing 307/1212 file: bacteria.183.1.genomic.fna.gz
# Saving 535 genomes from file : bacteria.183.1.genomic.fna.gz
# Prasing 308/1212 file: bacteria.184.1.genomic.fna.gz
# Saving 520 genomes from file : bacteria.184.1.genomic.fna.gz
# Prasing 309/1212 file: bacteria.185.1.genomic.fna.gz
# Saving 517 genomes from file : bacteria.185.1.genomic.fna.gz
# Prasing 310/1212 file: bacteria.186.1.genomic.fna.gz
# Saving 376 genomes from file : bacteria.186.1.genomic.fna.gz
# Prasing 311/1212 file: bacteria.187.1.genomic.fna.gz
# Saving 584 genomes from file : bacteria.187.1.genomic.fna.gz
# Prasing 312/1212 file: bacteria.188.1.genomic.fna.gz
# Saving 318 genomes from file : bacteria.188.1.genomic.fna.gz
# Prasing 313/1212 file: bacteria.189.1.genomic.fna.gz
# Saving 463 genomes from file : bacteria.189.1.genomic.fna.gz
# Prasing 314/1212 file: bacteria.19.1.genomic.fna.gz
# Saving 277 genomes from file : bacteria.19.1.genomic.fna.gz
# Prasing 315/1212 file: bacteria.190.1.genomic.fna.gz
# Saving 447 genomes from file : bacteria.190.1.genomic.fna.gz
# Prasing 316/1212 file: bacteria.191.1.genomic.fna.gz
# Saving 351 genomes from file : bacteria.191.1.genomic.fna.gz
# Prasing 317/1212 file: bacteria.192.1.genomic.fna.gz
# Saving 347 genomes from file : bacteria.192.1.genomic.fna.gz
# Prasing 318/1212 file: bacteria.193.1.genomic.fna.gz
# Saving 360 genomes from file : bacteria.193.1.genomic.fna.gz
# Prasing 319/1212 file: bacteria.194.1.genomic.fna.gz
# Saving 380 genomes from file : bacteria.194.1.genomic.fna.gz
# Prasing 320/1212 file: bacteria.195.1.genomic.fna.gz
# Saving 573 genomes from file : bacteria.195.1.genomic.fna.gz
# Prasing 321/1212 file: bacteria.196.1.genomic.fna.gz
# Saving 573 genomes from file : bacteria.196.1.genomic.fna.gz
# Prasing 322/1212 file: bacteria.197.1.genomic.fna.gz
# Saving 352 genomes from file : bacteria.197.1.genomic.fna.gz
# Prasing 323/1212 file: bacteria.198.1.genomic.fna.gz
# Saving 925 genomes from file : bacteria.198.1.genomic.fna.gz
# Prasing 324/1212 file: bacteria.199.1.genomic.fna.gz
# Saving 88 genomes from file : bacteria.199.1.genomic.fna.gz
# Prasing 325/1212 file: bacteria.2.1.genomic.fna.gz
# Saving 535 genomes from file : bacteria.2.1.genomic.fna.gz
# Prasing 326/1212 file: bacteria.20.1.genomic.fna.gz
# Saving 482 genomes from file : bacteria.20.1.genomic.fna.gz
# Prasing 327/1212 file: bacteria.200.1.genomic.fna.gz
# Saving 391 genomes from file : bacteria.200.1.genomic.fna.gz
# Prasing 328/1212 file: bacteria.201.1.genomic.fna.gz
# Saving 366 genomes from file : bacteria.201.1.genomic.fna.gz
# Prasing 329/1212 file: bacteria.202.1.genomic.fna.gz
# Saving 248 genomes from file : bacteria.202.1.genomic.fna.gz
# Prasing 330/1212 file: bacteria.203.1.genomic.fna.gz
# Saving 357 genomes from file : bacteria.203.1.genomic.fna.gz
# Prasing 331/1212 file: bacteria.204.1.genomic.fna.gz
# Saving 594 genomes from file : bacteria.204.1.genomic.fna.gz
# Prasing 332/1212 file: bacteria.205.1.genomic.fna.gz
# Saving 380 genomes from file : bacteria.205.1.genomic.fna.gz
# Prasing 333/1212 file: bacteria.206.1.genomic.fna.gz
# Saving 304 genomes from file : bacteria.206.1.genomic.fna.gz
# Prasing 334/1212 file: bacteria.207.1.genomic.fna.gz
# Saving 313 genomes from file : bacteria.207.1.genomic.fna.gz
# Prasing 335/1212 file: bacteria.208.1.genomic.fna.gz
# Saving 351 genomes from file : bacteria.208.1.genomic.fna.gz
# Prasing 336/1212 file: bacteria.209.1.genomic.fna.gz
# Saving 229 genomes from file : bacteria.209.1.genomic.fna.gz
# Prasing 337/1212 file: bacteria.21.1.genomic.fna.gz
# Saving 843 genomes from file : bacteria.21.1.genomic.fna.gz
# Prasing 338/1212 file: bacteria.210.1.genomic.fna.gz
# Saving 206 genomes from file : bacteria.210.1.genomic.fna.gz
# Prasing 339/1212 file: bacteria.211.1.genomic.fna.gz
# Saving 475 genomes from file : bacteria.211.1.genomic.fna.gz
# Prasing 340/1212 file: bacteria.212.1.genomic.fna.gz
# Saving 7 genomes from file : bacteria.212.1.genomic.fna.gz
# Prasing 341/1212 file: bacteria.213.1.genomic.fna.gz
# Saving 392 genomes from file : bacteria.213.1.genomic.fna.gz
# Prasing 342/1212 file: bacteria.214.1.genomic.fna.gz
# Saving 491 genomes from file : bacteria.214.1.genomic.fna.gz
# Prasing 343/1212 file: bacteria.215.1.genomic.fna.gz
# Saving 520 genomes from file : bacteria.215.1.genomic.fna.gz
# Prasing 344/1212 file: bacteria.216.1.genomic.fna.gz
# Saving 323 genomes from file : bacteria.216.1.genomic.fna.gz
# Prasing 345/1212 file: bacteria.217.1.genomic.fna.gz
# Saving 586 genomes from file : bacteria.217.1.genomic.fna.gz
# Prasing 346/1212 file: bacteria.218.1.genomic.fna.gz
# Saving 263 genomes from file : bacteria.218.1.genomic.fna.gz
# Prasing 347/1212 file: bacteria.219.1.genomic.fna.gz
# Saving 190 genomes from file : bacteria.219.1.genomic.fna.gz
# Prasing 348/1212 file: bacteria.22.1.genomic.fna.gz
# Saving 197 genomes from file : bacteria.22.1.genomic.fna.gz
# Prasing 349/1212 file: bacteria.220.1.genomic.fna.gz
# Saving 382 genomes from file : bacteria.220.1.genomic.fna.gz
# Prasing 350/1212 file: bacteria.221.1.genomic.fna.gz
# Saving 410 genomes from file : bacteria.221.1.genomic.fna.gz
# Prasing 351/1212 file: bacteria.222.1.genomic.fna.gz
# Saving 229 genomes from file : bacteria.222.1.genomic.fna.gz
# Prasing 352/1212 file: bacteria.223.1.genomic.fna.gz
# Saving 465 genomes from file : bacteria.223.1.genomic.fna.gz
# Prasing 353/1212 file: bacteria.224.1.genomic.fna.gz
# Saving 544 genomes from file : bacteria.224.1.genomic.fna.gz
# Prasing 354/1212 file: bacteria.225.1.genomic.fna.gz
# Saving 663 genomes from file : bacteria.225.1.genomic.fna.gz
# Prasing 355/1212 file: bacteria.226.1.genomic.fna.gz
# Saving 436 genomes from file : bacteria.226.1.genomic.fna.gz
# Prasing 356/1212 file: bacteria.227.1.genomic.fna.gz
# Saving 462 genomes from file : bacteria.227.1.genomic.fna.gz
# Prasing 357/1212 file: bacteria.228.1.genomic.fna.gz
# Saving 421 genomes from file : bacteria.228.1.genomic.fna.gz
# Prasing 358/1212 file: bacteria.229.1.genomic.fna.gz
# Saving 25 genomes from file : bacteria.229.1.genomic.fna.gz
# Prasing 359/1212 file: bacteria.23.1.genomic.fna.gz
# Saving 1034 genomes from file : bacteria.23.1.genomic.fna.gz
# Prasing 360/1212 file: bacteria.230.1.genomic.fna.gz
# Saving 504 genomes from file : bacteria.230.1.genomic.fna.gz
# Prasing 361/1212 file: bacteria.231.1.genomic.fna.gz
# Saving 781 genomes from file : bacteria.231.1.genomic.fna.gz
# Prasing 362/1212 file: bacteria.232.1.genomic.fna.gz
# Saving 614 genomes from file : bacteria.232.1.genomic.fna.gz
# Prasing 363/1212 file: bacteria.233.1.genomic.fna.gz
# Saving 680 genomes from file : bacteria.233.1.genomic.fna.gz
# Prasing 364/1212 file: bacteria.234.1.genomic.fna.gz
# Saving 788 genomes from file : bacteria.234.1.genomic.fna.gz
# Prasing 365/1212 file: bacteria.235.1.genomic.fna.gz
# Saving 641 genomes from file : bacteria.235.1.genomic.fna.gz
# Prasing 366/1212 file: bacteria.236.1.genomic.fna.gz
# Saving 647 genomes from file : bacteria.236.1.genomic.fna.gz
# Prasing 367/1212 file: bacteria.237.1.genomic.fna.gz
# Saving 4 genomes from file : bacteria.237.1.genomic.fna.gz
# Prasing 368/1212 file: bacteria.238.1.genomic.fna.gz
# Saving 503 genomes from file : bacteria.238.1.genomic.fna.gz
# Prasing 369/1212 file: bacteria.239.1.genomic.fna.gz
# Saving 571 genomes from file : bacteria.239.1.genomic.fna.gz
# Prasing 370/1212 file: bacteria.24.1.genomic.fna.gz
# Saving 26 genomes from file : bacteria.24.1.genomic.fna.gz
# Prasing 371/1212 file: bacteria.240.1.genomic.fna.gz
# Saving 639 genomes from file : bacteria.240.1.genomic.fna.gz
# Prasing 372/1212 file: bacteria.241.1.genomic.fna.gz
# Saving 578 genomes from file : bacteria.241.1.genomic.fna.gz
# Prasing 373/1212 file: bacteria.242.1.genomic.fna.gz
# Saving 642 genomes from file : bacteria.242.1.genomic.fna.gz
# Prasing 374/1212 file: bacteria.243.1.genomic.fna.gz
# Saving 582 genomes from file : bacteria.243.1.genomic.fna.gz
# Prasing 375/1212 file: bacteria.244.1.genomic.fna.gz
# Saving 483 genomes from file : bacteria.244.1.genomic.fna.gz
# Prasing 376/1212 file: bacteria.245.1.genomic.fna.gz
# Saving 531 genomes from file : bacteria.245.1.genomic.fna.gz
# Prasing 377/1212 file: bacteria.246.1.genomic.fna.gz
# Saving 90 genomes from file : bacteria.246.1.genomic.fna.gz
# Prasing 378/1212 file: bacteria.247.1.genomic.fna.gz
# Saving 559 genomes from file : bacteria.247.1.genomic.fna.gz
# Prasing 379/1212 file: bacteria.248.1.genomic.fna.gz
# Saving 577 genomes from file : bacteria.248.1.genomic.fna.gz
# Prasing 380/1212 file: bacteria.249.1.genomic.fna.gz
# Saving 767 genomes from file : bacteria.249.1.genomic.fna.gz
# Prasing 381/1212 file: bacteria.25.1.genomic.fna.gz
# Saving 580 genomes from file : bacteria.25.1.genomic.fna.gz
# Prasing 382/1212 file: bacteria.250.1.genomic.fna.gz
# Saving 818 genomes from file : bacteria.250.1.genomic.fna.gz
# Prasing 383/1212 file: bacteria.251.1.genomic.fna.gz
# Saving 671 genomes from file : bacteria.251.1.genomic.fna.gz
# Prasing 384/1212 file: bacteria.252.1.genomic.fna.gz
# Saving 1155 genomes from file : bacteria.252.1.genomic.fna.gz
# Prasing 385/1212 file: bacteria.253.1.genomic.fna.gz
# Saving 8 genomes from file : bacteria.253.1.genomic.fna.gz
# Prasing 386/1212 file: bacteria.254.1.genomic.fna.gz
# Saving 999 genomes from file : bacteria.254.1.genomic.fna.gz
# Prasing 387/1212 file: bacteria.255.1.genomic.fna.gz
# Saving 889 genomes from file : bacteria.255.1.genomic.fna.gz
# Prasing 388/1212 file: bacteria.256.1.genomic.fna.gz
# Saving 695 genomes from file : bacteria.256.1.genomic.fna.gz
# Prasing 389/1212 file: bacteria.257.1.genomic.fna.gz
# Saving 405 genomes from file : bacteria.257.1.genomic.fna.gz
# Prasing 390/1212 file: bacteria.258.1.genomic.fna.gz
# Saving 513 genomes from file : bacteria.258.1.genomic.fna.gz
# Prasing 391/1212 file: bacteria.259.1.genomic.fna.gz
# Saving 671 genomes from file : bacteria.259.1.genomic.fna.gz
# Prasing 392/1212 file: bacteria.26.1.genomic.fna.gz
# Saving 302 genomes from file : bacteria.26.1.genomic.fna.gz
# Prasing 393/1212 file: bacteria.260.1.genomic.fna.gz
# Saving 517 genomes from file : bacteria.260.1.genomic.fna.gz
# Prasing 394/1212 file: bacteria.261.1.genomic.fna.gz
# Saving 495 genomes from file : bacteria.261.1.genomic.fna.gz
# Prasing 395/1212 file: bacteria.262.1.genomic.fna.gz
# Saving 336 genomes from file : bacteria.262.1.genomic.fna.gz
# Prasing 396/1212 file: bacteria.263.1.genomic.fna.gz
# Saving 257 genomes from file : bacteria.263.1.genomic.fna.gz
# Prasing 397/1212 file: bacteria.264.1.genomic.fna.gz
# Saving 516 genomes from file : bacteria.264.1.genomic.fna.gz
# Prasing 398/1212 file: bacteria.265.1.genomic.fna.gz
# Saving 456 genomes from file : bacteria.265.1.genomic.fna.gz
# Prasing 399/1212 file: bacteria.266.1.genomic.fna.gz
# Saving 478 genomes from file : bacteria.266.1.genomic.fna.gz
# Prasing 400/1212 file: bacteria.267.1.genomic.fna.gz
# Saving 462 genomes from file : bacteria.267.1.genomic.fna.gz
# Prasing 401/1212 file: bacteria.268.1.genomic.fna.gz
# Saving 451 genomes from file : bacteria.268.1.genomic.fna.gz
# Prasing 402/1212 file: bacteria.269.1.genomic.fna.gz
# Saving 476 genomes from file : bacteria.269.1.genomic.fna.gz
# Prasing 403/1212 file: bacteria.27.1.genomic.fna.gz
# Saving 391 genomes from file : bacteria.27.1.genomic.fna.gz
# Prasing 404/1212 file: bacteria.270.1.genomic.fna.gz
# Saving 469 genomes from file : bacteria.270.1.genomic.fna.gz
# Prasing 405/1212 file: bacteria.271.1.genomic.fna.gz
# Saving 380 genomes from file : bacteria.271.1.genomic.fna.gz
# Prasing 406/1212 file: bacteria.272.1.genomic.fna.gz
# Saving 931 genomes from file : bacteria.272.1.genomic.fna.gz
# Prasing 407/1212 file: bacteria.273.1.genomic.fna.gz
# Saving 711 genomes from file : bacteria.273.1.genomic.fna.gz
# Prasing 408/1212 file: bacteria.274.1.genomic.fna.gz
# Saving 501 genomes from file : bacteria.274.1.genomic.fna.gz
# Prasing 409/1212 file: bacteria.275.1.genomic.fna.gz
# Saving 656 genomes from file : bacteria.275.1.genomic.fna.gz
# Prasing 410/1212 file: bacteria.276.1.genomic.fna.gz
# Saving 797 genomes from file : bacteria.276.1.genomic.fna.gz
# Prasing 411/1212 file: bacteria.277.1.genomic.fna.gz
# Saving 735 genomes from file : bacteria.277.1.genomic.fna.gz
# Prasing 412/1212 file: bacteria.278.1.genomic.fna.gz
# Saving 272 genomes from file : bacteria.278.1.genomic.fna.gz
# Prasing 413/1212 file: bacteria.279.1.genomic.fna.gz
# Saving 794 genomes from file : bacteria.279.1.genomic.fna.gz
# Prasing 414/1212 file: bacteria.28.1.genomic.fna.gz
# Saving 410 genomes from file : bacteria.28.1.genomic.fna.gz
# Prasing 415/1212 file: bacteria.280.1.genomic.fna.gz
# Saving 342 genomes from file : bacteria.280.1.genomic.fna.gz
# Prasing 416/1212 file: bacteria.281.1.genomic.fna.gz
# Saving 276 genomes from file : bacteria.281.1.genomic.fna.gz
# Prasing 417/1212 file: bacteria.282.1.genomic.fna.gz
# Saving 557 genomes from file : bacteria.282.1.genomic.fna.gz
# Prasing 418/1212 file: bacteria.283.1.genomic.fna.gz
# Saving 410 genomes from file : bacteria.283.1.genomic.fna.gz
# Prasing 419/1212 file: bacteria.284.1.genomic.fna.gz
# Saving 366 genomes from file : bacteria.284.1.genomic.fna.gz
# Prasing 420/1212 file: bacteria.285.1.genomic.fna.gz
# Saving 324 genomes from file : bacteria.285.1.genomic.fna.gz
# ...
# Saving 327 genomes from file : bacteria.874.1.genomic.fna.gz
# Prasing 1075/1212 file: bacteria.875.1.genomic.fna.gz
# Saving 521 genomes from file : bacteria.875.1.genomic.fna.gz
# Prasing 1076/1212 file: bacteria.876.1.genomic.fna.gz
# Saving 464 genomes from file : bacteria.876.1.genomic.fna.gz
# Prasing 1077/1212 file: bacteria.877.1.genomic.fna.gz
# Saving 457 genomes from file : bacteria.877.1.genomic.fna.gz
# Prasing 1078/1212 file: bacteria.878.1.genomic.fna.gz
# Saving 639 genomes from file : bacteria.878.1.genomic.fna.gz
# Prasing 1079/1212 file: bacteria.879.1.genomic.fna.gz
# Saving 591 genomes from file : bacteria.879.1.genomic.fna.gz
# Prasing 1080/1212 file: bacteria.88.1.genomic.fna.gz
# Saving 178 genomes from file : bacteria.88.1.genomic.fna.gz
# Prasing 1081/1212 file: bacteria.880.1.genomic.fna.gz
# Saving 639 genomes from file : bacteria.880.1.genomic.fna.gz
# Prasing 1082/1212 file: bacteria.881.1.genomic.fna.gz
# Saving 563 genomes from file : bacteria.881.1.genomic.fna.gz
# Prasing 1083/1212 file: bacteria.882.1.genomic.fna.gz
# Saving 558 genomes from file : bacteria.882.1.genomic.fna.gz
# Prasing 1084/1212 file: bacteria.883.1.genomic.fna.gz
# Saving 707 genomes from file : bacteria.883.1.genomic.fna.gz
# Prasing 1085/1212 file: bacteria.884.1.genomic.fna.gz
# Saving 809 genomes from file : bacteria.884.1.genomic.fna.gz
# Prasing 1086/1212 file: bacteria.885.1.genomic.fna.gz
# Saving 478 genomes from file : bacteria.885.1.genomic.fna.gz
# Prasing 1087/1212 file: bacteria.886.1.genomic.fna.gz
# Saving 540 genomes from file : bacteria.886.1.genomic.fna.gz
# Prasing 1088/1212 file: bacteria.887.1.genomic.fna.gz
# Saving 463 genomes from file : bacteria.887.1.genomic.fna.gz
# Prasing 1089/1212 file: bacteria.888.1.genomic.fna.gz
# Saving 490 genomes from file : bacteria.888.1.genomic.fna.gz
# Prasing 1090/1212 file: bacteria.889.1.genomic.fna.gz
# Saving 452 genomes from file : bacteria.889.1.genomic.fna.gz
# Prasing 1091/1212 file: bacteria.89.1.genomic.fna.gz
# Saving 526 genomes from file : bacteria.89.1.genomic.fna.gz
# Prasing 1092/1212 file: bacteria.890.1.genomic.fna.gz
# Saving 97 genomes from file : bacteria.890.1.genomic.fna.gz
# Prasing 1093/1212 file: bacteria.891.1.genomic.fna.gz
# Saving 391 genomes from file : bacteria.891.1.genomic.fna.gz
# Prasing 1094/1212 file: bacteria.892.1.genomic.fna.gz
# Saving 441 genomes from file : bacteria.892.1.genomic.fna.gz
# Prasing 1095/1212 file: bacteria.893.1.genomic.fna.gz
# Saving 460 genomes from file : bacteria.893.1.genomic.fna.gz
# Prasing 1096/1212 file: bacteria.894.1.genomic.fna.gz
# Saving 339 genomes from file : bacteria.894.1.genomic.fna.gz
# Prasing 1097/1212 file: bacteria.895.1.genomic.fna.gz
# Saving 435 genomes from file : bacteria.895.1.genomic.fna.gz
# Prasing 1098/1212 file: bacteria.896.1.genomic.fna.gz
# Saving 387 genomes from file : bacteria.896.1.genomic.fna.gz
# Prasing 1099/1212 file: bacteria.897.1.genomic.fna.gz
# Saving 505 genomes from file : bacteria.897.1.genomic.fna.gz
# Prasing 1100/1212 file: bacteria.898.1.genomic.fna.gz
# Saving 568 genomes from file : bacteria.898.1.genomic.fna.gz
# Prasing 1101/1212 file: bacteria.899.1.genomic.fna.gz
# Saving 615 genomes from file : bacteria.899.1.genomic.fna.gz
# Prasing 1102/1212 file: bacteria.9.1.genomic.fna.gz
# Saving 202 genomes from file : bacteria.9.1.genomic.fna.gz
# Prasing 1103/1212 file: bacteria.90.1.genomic.fna.gz
# Saving 558 genomes from file : bacteria.90.1.genomic.fna.gz
# Prasing 1104/1212 file: bacteria.900.1.genomic.fna.gz
# Saving 116 genomes from file : bacteria.900.1.genomic.fna.gz
# Prasing 1105/1212 file: bacteria.901.1.genomic.fna.gz
# Saving 533 genomes from file : bacteria.901.1.genomic.fna.gz
# Prasing 1106/1212 file: bacteria.902.1.genomic.fna.gz
# Saving 423 genomes from file : bacteria.902.1.genomic.fna.gz
# Prasing 1107/1212 file: bacteria.903.1.genomic.fna.gz
# Saving 473 genomes from file : bacteria.903.1.genomic.fna.gz
# Prasing 1108/1212 file: bacteria.904.1.genomic.fna.gz
# Saving 514 genomes from file : bacteria.904.1.genomic.fna.gz
# Prasing 1109/1212 file: bacteria.905.1.genomic.fna.gz
# Saving 382 genomes from file : bacteria.905.1.genomic.fna.gz
# Prasing 1110/1212 file: bacteria.906.1.genomic.fna.gz
# Saving 550 genomes from file : bacteria.906.1.genomic.fna.gz
# Prasing 1111/1212 file: bacteria.907.1.genomic.fna.gz
# Saving 324 genomes from file : bacteria.907.1.genomic.fna.gz
# Prasing 1112/1212 file: bacteria.908.1.genomic.fna.gz
# Saving 671 genomes from file : bacteria.908.1.genomic.fna.gz
# Prasing 1113/1212 file: bacteria.909.1.genomic.fna.gz
# Saving 701 genomes from file : bacteria.909.1.genomic.fna.gz
# Prasing 1114/1212 file: bacteria.91.1.genomic.fna.gz
# Saving 572 genomes from file : bacteria.91.1.genomic.fna.gz
# Prasing 1115/1212 file: bacteria.910.1.genomic.fna.gz
# Saving 585 genomes from file : bacteria.910.1.genomic.fna.gz
# Prasing 1116/1212 file: bacteria.911.1.genomic.fna.gz
# Saving 739 genomes from file : bacteria.911.1.genomic.fna.gz
# Prasing 1117/1212 file: bacteria.912.1.genomic.fna.gz
# Saving 483 genomes from file : bacteria.912.1.genomic.fna.gz
# Prasing 1118/1212 file: bacteria.913.1.genomic.fna.gz
# Saving 648 genomes from file : bacteria.913.1.genomic.fna.gz
# Prasing 1119/1212 file: bacteria.914.1.genomic.fna.gz
# Saving 555 genomes from file : bacteria.914.1.genomic.fna.gz
# Prasing 1120/1212 file: bacteria.915.1.genomic.fna.gz
# Saving 476 genomes from file : bacteria.915.1.genomic.fna.gz
# Prasing 1121/1212 file: bacteria.916.1.genomic.fna.gz
# Saving 383 genomes from file : bacteria.916.1.genomic.fna.gz
# Prasing 1122/1212 file: bacteria.917.1.genomic.fna.gz
# Saving 502 genomes from file : bacteria.917.1.genomic.fna.gz
# Prasing 1123/1212 file: bacteria.918.1.genomic.fna.gz
# Saving 443 genomes from file : bacteria.918.1.genomic.fna.gz
# Prasing 1124/1212 file: bacteria.919.1.genomic.fna.gz
# Saving 501 genomes from file : bacteria.919.1.genomic.fna.gz
# Prasing 1125/1212 file: bacteria.92.1.genomic.fna.gz
# Saving 878 genomes from file : bacteria.92.1.genomic.fna.gz
# Prasing 1126/1212 file: bacteria.920.1.genomic.fna.gz
# Saving 598 genomes from file : bacteria.920.1.genomic.fna.gz
# Prasing 1127/1212 file: bacteria.921.1.genomic.fna.gz
# Saving 512 genomes from file : bacteria.921.1.genomic.fna.gz
# Prasing 1128/1212 file: bacteria.922.1.genomic.fna.gz
# Saving 1140 genomes from file : bacteria.922.1.genomic.fna.gz
# Prasing 1129/1212 file: bacteria.923.1.genomic.fna.gz
# Saving 595 genomes from file : bacteria.923.1.genomic.fna.gz
# Prasing 1130/1212 file: bacteria.924.1.genomic.fna.gz
# Saving 869 genomes from file : bacteria.924.1.genomic.fna.gz
# Prasing 1131/1212 file: bacteria.925.1.genomic.fna.gz
# Saving 904 genomes from file : bacteria.925.1.genomic.fna.gz
# Prasing 1132/1212 file: bacteria.926.1.genomic.fna.gz
# Saving 863 genomes from file : bacteria.926.1.genomic.fna.gz
# Prasing 1133/1212 file: bacteria.927.1.genomic.fna.gz
# Saving 862 genomes from file : bacteria.927.1.genomic.fna.gz
# Prasing 1134/1212 file: bacteria.928.1.genomic.fna.gz
# Saving 723 genomes from file : bacteria.928.1.genomic.fna.gz
# Prasing 1135/1212 file: bacteria.929.1.genomic.fna.gz
# Saving 553 genomes from file : bacteria.929.1.genomic.fna.gz
# Prasing 1136/1212 file: bacteria.93.1.genomic.fna.gz
# Saving 776 genomes from file : bacteria.93.1.genomic.fna.gz
# Prasing 1137/1212 file: bacteria.930.1.genomic.fna.gz
# Saving 732 genomes from file : bacteria.930.1.genomic.fna.gz
# Prasing 1138/1212 file: bacteria.931.1.genomic.fna.gz
# Saving 583 genomes from file : bacteria.931.1.genomic.fna.gz
# Prasing 1139/1212 file: bacteria.932.1.genomic.fna.gz
# Saving 331 genomes from file : bacteria.932.1.genomic.fna.gz
# Prasing 1140/1212 file: bacteria.933.1.genomic.fna.gz
# Saving 267 genomes from file : bacteria.933.1.genomic.fna.gz
# Prasing 1141/1212 file: bacteria.934.1.genomic.fna.gz
# Saving 470 genomes from file : bacteria.934.1.genomic.fna.gz
# Prasing 1142/1212 file: bacteria.935.1.genomic.fna.gz
# Saving 1172 genomes from file : bacteria.935.1.genomic.fna.gz
# Prasing 1143/1212 file: bacteria.936.1.genomic.fna.gz
# Saving 1092 genomes from file : bacteria.936.1.genomic.fna.gz
# Prasing 1144/1212 file: bacteria.937.1.genomic.fna.gz
# Saving 25 genomes from file : bacteria.937.1.genomic.fna.gz
# Prasing 1145/1212 file: bacteria.938.1.genomic.fna.gz
# Saving 827 genomes from file : bacteria.938.1.genomic.fna.gz
# Prasing 1146/1212 file: bacteria.939.1.genomic.fna.gz
# Saving 1140 genomes from file : bacteria.939.1.genomic.fna.gz
# Prasing 1147/1212 file: bacteria.94.1.genomic.fna.gz
# Saving 829 genomes from file : bacteria.94.1.genomic.fna.gz
# Prasing 1148/1212 file: bacteria.940.1.genomic.fna.gz
# Saving 955 genomes from file : bacteria.940.1.genomic.fna.gz
# Prasing 1149/1212 file: bacteria.941.1.genomic.fna.gz
# Saving 878 genomes from file : bacteria.941.1.genomic.fna.gz
# Prasing 1150/1212 file: bacteria.942.1.genomic.fna.gz
# Saving 510 genomes from file : bacteria.942.1.genomic.fna.gz
# Prasing 1151/1212 file: bacteria.943.1.genomic.fna.gz
# Saving 439 genomes from file : bacteria.943.1.genomic.fna.gz
# Prasing 1152/1212 file: bacteria.944.1.genomic.fna.gz
# Saving 1018 genomes from file : bacteria.944.1.genomic.fna.gz
# Prasing 1153/1212 file: bacteria.945.1.genomic.fna.gz
# Saving 698 genomes from file : bacteria.945.1.genomic.fna.gz
# Prasing 1154/1212 file: bacteria.946.1.genomic.fna.gz
# Saving 839 genomes from file : bacteria.946.1.genomic.fna.gz
# Prasing 1155/1212 file: bacteria.947.1.genomic.fna.gz
# Saving 694 genomes from file : bacteria.947.1.genomic.fna.gz
# Prasing 1156/1212 file: bacteria.948.1.genomic.fna.gz
# Saving 1345 genomes from file : bacteria.948.1.genomic.fna.gz
# Prasing 1157/1212 file: bacteria.949.1.genomic.fna.gz
# Saving 72 genomes from file : bacteria.949.1.genomic.fna.gz
# Prasing 1158/1212 file: bacteria.95.1.genomic.fna.gz
# Saving 168 genomes from file : bacteria.95.1.genomic.fna.gz
# Prasing 1159/1212 file: bacteria.950.1.genomic.fna.gz
# Saving 2028 genomes from file : bacteria.950.1.genomic.fna.gz
# Prasing 1160/1212 file: bacteria.951.1.genomic.fna.gz
# Saving 2288 genomes from file : bacteria.951.1.genomic.fna.gz
# Prasing 1161/1212 file: bacteria.952.1.genomic.fna.gz
# Saving 338 genomes from file : bacteria.952.1.genomic.fna.gz
# Prasing 1162/1212 file: bacteria.953.1.genomic.fna.gz
# Saving 1293 genomes from file : bacteria.953.1.genomic.fna.gz
# Prasing 1163/1212 file: bacteria.954.1.genomic.fna.gz
# Saving 424 genomes from file : bacteria.954.1.genomic.fna.gz
# Prasing 1164/1212 file: bacteria.955.1.genomic.fna.gz
# Saving 855 genomes from file : bacteria.955.1.genomic.fna.gz
# Prasing 1165/1212 file: bacteria.956.1.genomic.fna.gz
# Saving 872 genomes from file : bacteria.956.1.genomic.fna.gz
# Prasing 1166/1212 file: bacteria.957.1.genomic.fna.gz
# Saving 572 genomes from file : bacteria.957.1.genomic.fna.gz
# Prasing 1167/1212 file: bacteria.958.1.genomic.fna.gz
# Saving 713 genomes from file : bacteria.958.1.genomic.fna.gz
# Prasing 1168/1212 file: bacteria.959.1.genomic.fna.gz
# Saving 98 genomes from file : bacteria.959.1.genomic.fna.gz
# Prasing 1169/1212 file: bacteria.96.1.genomic.fna.gz
# Saving 964 genomes from file : bacteria.96.1.genomic.fna.gz
# Prasing 1170/1212 file: bacteria.960.1.genomic.fna.gz
# Saving 323 genomes from file : bacteria.960.1.genomic.fna.gz
# Prasing 1171/1212 file: bacteria.961.1.genomic.fna.gz
# Saving 1118 genomes from file : bacteria.961.1.genomic.fna.gz
# Prasing 1172/1212 file: bacteria.962.1.genomic.fna.gz
# Saving 649 genomes from file : bacteria.962.1.genomic.fna.gz
# Prasing 1173/1212 file: bacteria.963.1.genomic.fna.gz
# Saving 166 genomes from file : bacteria.963.1.genomic.fna.gz
# Prasing 1174/1212 file: bacteria.964.1.genomic.fna.gz
# Saving 200 genomes from file : bacteria.964.1.genomic.fna.gz
# Prasing 1175/1212 file: bacteria.965.1.genomic.fna.gz
# Saving 286 genomes from file : bacteria.965.1.genomic.fna.gz
# Prasing 1176/1212 file: bacteria.966.1.genomic.fna.gz
# Saving 385 genomes from file : bacteria.966.1.genomic.fna.gz
# Prasing 1177/1212 file: bacteria.967.1.genomic.fna.gz
# Saving 345 genomes from file : bacteria.967.1.genomic.fna.gz
# Prasing 1178/1212 file: bacteria.968.1.genomic.fna.gz
# Saving 320 genomes from file : bacteria.968.1.genomic.fna.gz
# Prasing 1179/1212 file: bacteria.969.1.genomic.fna.gz
# Saving 553 genomes from file : bacteria.969.1.genomic.fna.gz
# Prasing 1180/1212 file: bacteria.97.1.genomic.fna.gz
# Saving 1210 genomes from file : bacteria.97.1.genomic.fna.gz
# Prasing 1181/1212 file: bacteria.970.1.genomic.fna.gz
# Saving 324 genomes from file : bacteria.970.1.genomic.fna.gz
# Prasing 1182/1212 file: bacteria.971.1.genomic.fna.gz
# Saving 1280 genomes from file : bacteria.971.1.genomic.fna.gz
# Prasing 1183/1212 file: bacteria.972.1.genomic.fna.gz
# Saving 1331 genomes from file : bacteria.972.1.genomic.fna.gz
# Prasing 1184/1212 file: bacteria.973.1.genomic.fna.gz
# Saving 1008 genomes from file : bacteria.973.1.genomic.fna.gz
# Prasing 1185/1212 file: bacteria.974.1.genomic.fna.gz
# Saving 796 genomes from file : bacteria.974.1.genomic.fna.gz
# Prasing 1186/1212 file: bacteria.975.1.genomic.fna.gz
# Saving 234 genomes from file : bacteria.975.1.genomic.fna.gz
# Prasing 1187/1212 file: bacteria.976.1.genomic.fna.gz
# Saving 492 genomes from file : bacteria.976.1.genomic.fna.gz
# Prasing 1188/1212 file: bacteria.977.1.genomic.fna.gz
# Saving 413 genomes from file : bacteria.977.1.genomic.fna.gz
# Prasing 1189/1212 file: bacteria.978.1.genomic.fna.gz
# Saving 241 genomes from file : bacteria.978.1.genomic.fna.gz
# Prasing 1190/1212 file: bacteria.979.1.genomic.fna.gz
# Saving 8 genomes from file : bacteria.979.1.genomic.fna.gz
# Prasing 1191/1212 file: bacteria.98.1.genomic.fna.gz
# Saving 1146 genomes from file : bacteria.98.1.genomic.fna.gz
# Prasing 1192/1212 file: bacteria.980.1.genomic.fna.gz
# Saving 47 genomes from file : bacteria.980.1.genomic.fna.gz
# Prasing 1193/1212 file: bacteria.981.1.genomic.fna.gz
# Saving 63 genomes from file : bacteria.981.1.genomic.fna.gz
# Prasing 1194/1212 file: bacteria.982.1.genomic.fna.gz
# Saving 58 genomes from file : bacteria.982.1.genomic.fna.gz
# Prasing 1195/1212 file: bacteria.983.1.genomic.fna.gz
# Saving 42 genomes from file : bacteria.983.1.genomic.fna.gz
# Prasing 1196/1212 file: bacteria.984.1.genomic.fna.gz
# Saving 27 genomes from file : bacteria.984.1.genomic.fna.gz
# Prasing 1197/1212 file: bacteria.985.1.genomic.fna.gz
# Saving 28 genomes from file : bacteria.985.1.genomic.fna.gz
# Prasing 1198/1212 file: bacteria.986.1.genomic.fna.gz
# Saving 32 genomes from file : bacteria.986.1.genomic.fna.gz
# Prasing 1199/1212 file: bacteria.987.1.genomic.fna.gz
# Saving 30 genomes from file : bacteria.987.1.genomic.fna.gz
# Prasing 1200/1212 file: bacteria.988.1.genomic.fna.gz
# Saving 41 genomes from file : bacteria.988.1.genomic.fna.gz
# Prasing 1201/1212 file: bacteria.989.1.genomic.fna.gz
# Saving 65 genomes from file : bacteria.989.1.genomic.fna.gz
# Prasing 1202/1212 file: bacteria.99.1.genomic.fna.gz
# Saving 1141 genomes from file : bacteria.99.1.genomic.fna.gz
# Prasing 1203/1212 file: bacteria.990.1.genomic.fna.gz
# Saving 166 genomes from file : bacteria.990.1.genomic.fna.gz
# Prasing 1204/1212 file: bacteria.991.1.genomic.fna.gz
# Saving 97 genomes from file : bacteria.991.1.genomic.fna.gz
# Prasing 1205/1212 file: bacteria.992.1.genomic.fna.gz
# Saving 49 genomes from file : bacteria.992.1.genomic.fna.gz
# Prasing 1206/1212 file: bacteria.993.1.genomic.fna.gz
# Saving 65 genomes from file : bacteria.993.1.genomic.fna.gz
# Prasing 1207/1212 file: bacteria.994.1.genomic.fna.gz
# Saving 59 genomes from file : bacteria.994.1.genomic.fna.gz
# Prasing 1208/1212 file: bacteria.995.1.genomic.fna.gz
# Saving 40 genomes from file : bacteria.995.1.genomic.fna.gz
# Prasing 1209/1212 file: bacteria.996.1.genomic.fna.gz
# Saving 367 genomes from file : bacteria.996.1.genomic.fna.gz
# Prasing 1210/1212 file: bacteria.997.1.genomic.fna.gz
# Saving 112 genomes from file : bacteria.997.1.genomic.fna.gz
# Prasing 1211/1212 file: bacteria.998.1.genomic.fna.gz
# Saving 33 genomes from file : bacteria.998.1.genomic.fna.gz
# Prasing 1212/1212 file: bacteria.999.1.genomic.fna.gz
# Saving 65 genomes from file : bacteria.999.1.genomic.fna.gz
# Saved 525015 genomes in E:/masters/virnet/data/1-genomes\bacteria.fna
# Time elapased 154.843 Minutes

# %% [markdown]
# Merge Archea and Bacteria

# %%
# !copy E:\masters\virnet\data\1-genomes\archaea.fna + E:\masters\virnet\data\1-genomes\bacteria.fna  E:\masters\virnet\data\1-genomes\non_viral.fna
# Out:
# E:\masters\virnet\data\1-genomes\archaea.fna
# E:\masters\virnet\data\1-genomes\bacteria.fna
#         1 file(s) copied.

# %% [markdown]
# ## 2- Split Genomes

# %%
def split_sample_genomes(genometype,input_folder,output_folder,sample=False):
    random.seed(42)
    start=time.time()
    fasta_file=os.path.join(input_folder,"{0}.fna".format(genometype))
    train_file=os.path.join(output_folder,"{0}_train.fna".format(genometype))
    test_file=os.path.join(output_folder,"{0}_test.fna".format(genometype))
    count=0
    pb_count=0
    t_count=0
    t_pb_count=0
    print('Reading and Splitting {0} genomes'.format(genometype))
    with open(fasta_file,"rt") as handle , open(train_file,'w+') as train_f, open(test_file,'w+') as test_f:
        for record in SeqIO.parse(handle, "fasta"):
            if(sample==True and random.randint(0,2)!=0):
                continue
            toss=random.randint(1,10)
            if(toss==4 or toss==7):
                test_f.write('>{0}\n{1}\n'.format(record.id,record.seq))
                t_count+=1
                t_pb_count+=len(record.seq)
            else:
                train_f.write('>{0}\n{1}\n'.format(record.id,record.seq))
                count+=1
                pb_count+=len(record.seq)
    end=time.time()
    print('Training {0} genomes'.format(count))
    print('Testing {0} genomes'.format(t_count))
    print('Training bp ratio {0:.3f}%'.format(pb_count*100.0/(pb_count+t_pb_count)))
    print('Total bp {0}'.format(pb_count+t_pb_count))
    print('Time elapased {0:.3f} Sec'.format(end-start))

# %%
split_sample_genomes('viral',genome_folder,train_test_folder)
# Out:
# Reading and Splitting viral genomes
# Training 7686 genomes
# Testing 1870 genomes
# Training bp ratio 79.852%
# Total bp 261109346
# Time elapased 3.313 Sec

# %%
split_sample_genomes('non_viral',genome_folder,train_test_folder,sample=True)
# Out:
# Reading and Splitting non_viral genomes
# Training 143241 genomes
# Testing 35543 genomes
# Training bp ratio 80.345%
# Time elapased 432.700 Sec

# %% [markdown]
# ## 3- Generate Fragments

# %%
def rand_parts(seq, n_gen, contigs_len):
    indices = range(len(seq) - (contigs_len - 1) * n_gen)
    result = []
    offset = 0
    for i in sorted(random.sample(indices, n_gen)):
        i += offset
        result.append(str(seq[i:i+contigs_len]))        
        offset += contigs_len - 1
    return result

def get_sequences(seq,contigs_len=500,is_random=False):
    if is_random:
        n_gen=random.randint(0,50)
        if (len(seq)>contigs_len):
            if (len(seq)<contigs_len*n_gen):
                start=random.randint(0,len(seq) - (contigs_len - 1))
                return [str(seq[start:start+contigs_len])]
            else:
                return rand_parts(seq,n_gen,contigs_len)
        else:
            return []
    else:
        seq_list=[]
        n_gen=len(seq)//contigs_len
        for i in range(n_gen):
            start=i*contigs_len   
            end=start+contigs_len
            seq_list.append(str(seq[start:end]))    
        ## Adding the last contigs with the perivous (The last contigs is overlapping TODO fix)
        seq_list.append(str(seq[-contigs_len:]))
        return seq_list
    
def generate_fragment(file,input_folder,output_folder,n,sample=False):
    random.seed(42)
    start=time.time()
    file_path=os.path.join(input_folder,file)
    output_path=os.path.join(output_folder,"{0}_{1}.fna".format(file,n))
    n_reads=0
    with open(file_path,'rt') as handle, open(output_path,'w+') as out_f:
        for record in SeqIO.parse(handle, "fasta"):
            generated_sequences=get_sequences(record.seq,contigs_len=n,is_random=sample)
            n_reads+=len(generated_sequences)
            for item in generated_sequences:
                out_f.write('>{0}\n{1}\n'.format(record.id,item))
    end=time.time()
    print('Generated reads {0}'.format(n_reads))
    print('Time elapased {0:.3f} Sec'.format(end-start))

# %%
generate_fragment('viral_train.fna',train_test_folder,fragments_folder,n=100)
generate_fragment('viral_test.fna',train_test_folder,fragments_folder,n=100)
# Out:
# Generated reads 2088863
# Time elapased 8.974 Sec
# Generated reads 527020
# Time elapased 2.376 Sec

# %%
generate_fragment('non_viral_test.fna',train_test_folder,fragments_folder,n=100,sample=True)
generate_fragment('non_viral_train.fna',train_test_folder,fragments_folder,n=100,sample=True)
# Out:
# Generated reads 517673
# Time elapased 10.981 Sec
# Generated reads 2094125
# Time elapased 80.865 Sec

# %% [markdown]
# ## 4- Generate Metagenomes

# %%
def create_metagenome_genomes(file,reads,read_len,viral_ratio):
    random.seed(42)
    print("Starting creating genomes for {0}".format(file))
    start=time.time()
    total_length=reads*read_len
    output_file=os.path.join(metagenome_folder,"{0}.fna".format(file))


    viral_path=os.path.join(train_test_folder,'viral_test.fna')
    non_viral_path=os.path.join(train_test_folder,'non_viral_test.fna')

    vfaa = list(Fasta(viral_path))
    bfaa = list(Fasta(non_viral_path))

    random.shuffle(vfaa)
    random.shuffle(bfaa)

    v_len=0
    v_count=0
    b_len=0
    b_count=0
    with open(output_file,'w+') as fout:
        print("Sample from Viruses")
        for sample in vfaa:
            if(v_len>=int(total_length*viral_ratio)):
                break
            fout.write('>{0}\n{1}\n'.format(sample.name,sample))
            v_len+=len(sample)
            v_count+=1
        print('Viruses Length {0} bp'.format(v_len))
        print('# Viruses Genomes {0}'.format(v_count))

        print("Sample from Bacteria")
        for sample in bfaa:
            if(v_len*1.0/(v_len+b_len)<=viral_ratio):
                break
            fout.write('>{0}\n{1}\n'.format(sample.name,sample))
            b_len+=len(sample)
            b_count+=1
    print('Bacteria Length {0} bp'.format(b_len))
    print('# Bacteria Genomes {0}'.format(b_count))
    end=time.time()
    print('Time elapased {0:3f} Secs'.format(end-start))
    print('Total Length {0} bp'.format(v_len+b_len))
    print('Bacteria ratio {0:.2f}%'.format(b_len*1.0/(v_len+b_len)*100))

# %%
create_metagenome_genomes('microbiome',reads=10**6,read_len=100,viral_ratio=0.25)
create_metagenome_genomes('virome',reads=10**6,read_len=100,viral_ratio=0.75)
# Out:
# Starting creating genomes for microbiome
# Sample from Viruses
# Viruses Length 25133078 bp
# # Viruses Genomes 845
# Sample from Bacteria
# Bacteria Length 75450367 bp
# # Bacteria Genomes 1488
# Time elapased 11.989594 Secs
# Total Length 100583445 bp
# Bacteria ratio 75.01%
# Starting creating genomes for virome
# Sample from Viruses
# Viruses Length 52609236 bp
# # Viruses Genomes 1870
# Sample from Bacteria
# Bacteria Length 17551396 bp
# # Bacteria Genomes 422
# Time elapased 1.445022 Secs
# Total Length 70160632 bp
# Bacteria ratio 25.02%

# %% [markdown]
# ## 5- Real case Study
